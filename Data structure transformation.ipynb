# %% [markdown]
# Необходимо на заданном наборе данных провести его преобразование к формату, пригодном для построения модели линейной регрессии. Затем по каждой уникальной комбинации значений переменных Object и Energy_Source в рамках каждого уникального значения переменной Organization произвести расчет следующих параметров модели линейной регрессии:
# <ul>
# <li>Значение свободного члена модели (записать только для переменной с названием Consumption, для остальных заполнить nan)</li>
# <li>Коэффициенты регрессии для переменных модели (кроме свободного члена)</li>
# <li>Значения p-value для t-теста о значимости коэффициентов регрессии (кроме свободного члена)</li>
# <li>Бинарный индикатор прохождения коэффициентами регрессии t-теста о значимости (кроме свободного члена)</li>
# <li>Значение p-value для F-теста о значимости регрессии в целом (записать только для переменной с названием Consumption, для остальных заполнить nan)</li>
# <li>Значение скорректированного коэффициента детерминации R2 Adjusted (записать только для переменной с названием Consumption, для остальных заполнить nan)</li>
# </ul>
#
# Результаты всех моделей записать в единый датафрейм pandas.
#
# В расчетах не учитывать строки со значением переменной Consumption=0.<p>
# В случае отсутствия данных для расчета модели выдавать датафрейм с nan значениями.

# %%
# -*- coding: utf-8 -*-

import pandas as pd
import numpy as np
import statsmodels.api as sm
import itertools
import warnings
warnings.filterwarnings("ignore")

### Без создания формулы модели ###

def make_new_DF(initialDF):
### Создает датафрейм с переменными - столбцами ###
    categorials = initialDF.columns.tolist()[:2]	# берем объект и энергоресурс
    features = initialDF.Feature.unique().tolist()	# берем названия переменных
    new_df_cols = categorials+features	# соединяем
    new_DF = pd.DataFrame(data=None, columns=new_df_cols)	# создаем датафрейм с новыми столбцами 
    return new_DF

def fill_new_DF(initialDF, new_DF, cat1, cat2):
### Заполняет созданный датафрейм данными из исходного ###
    features = initialDF.Feature.unique().tolist()	# список переменных
    for feature in features:
        new_DF[feature]=initialDF.Value[initialDF.Feature==feature].values	# заполняем столбец каждой переменной данными
    new_DF.Object.fillna(value=cat1, inplace=True)	# заполняем значение объекта
    new_DF.Energy_Source.fillna(value=cat2, inplace=True)	# заполняем значение энергоресурса
    return new_DF

def generate_out_df(model, Cube_Variables, object, output_DF_cols):
### Генерирует выходной датафрейм на основании расчитанной модели ###
### Заполняет значения пустого пересечения показателей*переменных null-значением ###
    output_DF = pd.DataFrame(data=None, columns=output_DF_cols)
    null_indicator = np.nan

    # заполняем значения по переменным из модели
    output_DF['Cube_Variable'] = Cube_Variables[1:]
    output_DF["coef"] = model.params[1:].tolist()
    output_DF["p_value"] = model.pvalues[1:].tolist()
    output_DF["Usefull"] = np.where(output_DF["p_value"]<=threshold, 1, 0)
    output_DF["Object"] = object
    output_DF["p_value"].loc[output_DF.p_value.isnull()==True]=1
    output_DF['r2_adj'] = null_indicator
    output_DF['Intercept'] = null_indicator
    output_DF['Significance'] = null_indicator
    
    # заполняем общие значения по модели 
    general_values = pd.DataFrame([[object, Cube_Variables[0], model.rsquared_adj, model.params[0], model.f_pvalue, null_indicator, null_indicator, null_indicator]], columns=output_DF_cols)
    output_DF = output_DF.append(general_values, ignore_index=True)
    return output_DF

def generate_blank_out_df(Cube_Variables, object, output_DF_cols):
### Генерирует пустой выходной датафрейм, если расчет ведется на пустых данных ###
### Заполняет значения коэффициентов нулями, все остальные числовые показатели заполняет null-значением ###
    output_DF = pd.DataFrame(data=None, columns=output_DF_cols)
    null_indicator = np.nan

    output_DF['Cube_Variable'] = Cube_Variables
    output_DF["coef"] = 0
    output_DF["p_value"] = null_indicator
    output_DF["r2_adj"] = null_indicator
    output_DF['Intercept'] = null_indicator
    output_DF["Usefull"] = null_indicator
    output_DF["Object"] = object
    output_DF["Significance"] = null_indicator
    return output_DF
# Out:
# /Users/maximhorin/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
df = pd.read_excel("sample_data.xlsx")

# %%
df
# Out:
#       Object     Energy_Source      Feature   Value      Date Organization  \
# 0       Obj1   Energy source 1  Consumption  730691  01.01.17         Org1
# 1       Obj1   Energy source 1   Variable_1     953  01.01.17         Org1
# 2       Obj1   Energy source 1   Variable_2     499  01.01.17         Org1
# 3       Obj1   Energy source 1   Variable_3       0  01.01.17         Org1
# 4       Obj1   Energy source 1   Variable_4       0  01.01.17         Org1
# 5       Obj1   Energy source 1   Variable_5       0  01.01.17         Org1
# 6       Obj1   Energy source 1   Variable_6       0  01.01.17         Org1
# 7       Obj1   Energy source 2  Consumption       0  01.01.17         Org1
# 8       Obj1   Energy source 2   Variable_1       0  01.01.17         Org1
# 9       Obj1   Energy source 2   Variable_2       0  01.01.17         Org1
# 10      Obj1   Energy source 2   Variable_3       0  01.01.17         Org1
# 11      Obj1   Energy source 2   Variable_4       0  01.01.17         Org1
# 12      Obj1   Energy source 2   Variable_5       0  01.01.17         Org1
# 13      Obj1   Energy source 2   Variable_6       0  01.01.17         Org1
# 14      Obj1   Energy source 3  Consumption       0  01.01.17         Org1
# 15      Obj1   Energy source 3   Variable_1       0  01.01.17         Org1
# 16      Obj1   Energy source 3   Variable_2       0  01.01.17         Org1
# 17      Obj1   Energy source 3   Variable_3       0  01.01.17         Org1
# 18      Obj1   Energy source 3   Variable_4       0  01.01.17         Org1
# 19      Obj1   Energy source 3   Variable_5       0  01.01.17         Org1
# 20      Obj1   Energy source 3   Variable_6       0  01.01.17         Org1
# 21      Obj1   Energy source 4  Consumption       0  01.01.17         Org1
# 22      Obj1   Energy source 4   Variable_1       0  01.01.17         Org1
# 23      Obj1   Energy source 4   Variable_2       0  01.01.17         Org1
# 24      Obj1   Energy source 4   Variable_3       0  01.01.17         Org1
# 25      Obj1   Energy source 4   Variable_4       0  01.01.17         Org1
# 26      Obj1   Energy source 4   Variable_5       0  01.01.17         Org1
# 27      Obj1   Energy source 4   Variable_6       0  01.01.17         Org1
# 28      Obj1   Energy source 5  Consumption       0  01.01.17         Org1
# 29      Obj1   Energy source 5   Variable_1       0  01.01.17         Org1
# ...      ...               ...          ...     ...       ...          ...
# 76620   Obj3   Energy source 6   Variable_5       0  31.12.17         Org1
# 76621   Obj3   Energy source 6   Variable_6       0  31.12.17         Org1
# 76622   Obj3   Energy source 7  Consumption       0  31.12.17         Org1
# 76623   Obj3   Energy source 7   Variable_1       0  31.12.17         Org1
# 76624   Obj3   Energy source 7   Variable_2       0  31.12.17         Org1
# 76625   Obj3   Energy source 7   Variable_3       0  31.12.17         Org1
# 76626   Obj3   Energy source 7   Variable_4       0  31.12.17         Org1
# 76627   Obj3   Energy source 7   Variable_5       0  31.12.17         Org1
# 76628   Obj3   Energy source 7   Variable_6       0  31.12.17         Org1
# 76629   Obj3   Energy source 8  Consumption       0  31.12.17         Org1
# 76630   Obj3   Energy source 8   Variable_1       0  31.12.17         Org1
# 76631   Obj3   Energy source 8   Variable_2       0  31.12.17         Org1
# 76632   Obj3   Energy source 8   Variable_3       0  31.12.17         Org1
# 76633   Obj3   Energy source 8   Variable_4       0  31.12.17         Org1
# 76634   Obj3   Energy source 8   Variable_5       0  31.12.17         Org1
# 76635   Obj3   Energy source 8   Variable_6       0  31.12.17         Org1
# 76636   Obj3   Energy source 9  Consumption       0  31.12.17         Org1
# 76637   Obj3   Energy source 9   Variable_1       0  31.12.17         Org1
# 76638   Obj3   Energy source 9   Variable_2       0  31.12.17         Org1
# 76639   Obj3   Energy source 9   Variable_3       0  31.12.17         Org1
# 76640   Obj3   Energy source 9   Variable_4       0  31.12.17         Org1
# 76641   Obj3   Energy source 9   Variable_5       0  31.12.17         Org1
# 76642   Obj3   Energy source 9   Variable_6       0  31.12.17         Org1
# 76643   Obj3  Energy source 10  Consumption       0  31.12.17         Org1
# 76644   Obj3  Energy source 10   Variable_1       0  31.12.17         Org1
# 76645   Obj3  Energy source 10   Variable_2       0  31.12.17         Org1
# 76646   Obj3  Energy source 10   Variable_3       0  31.12.17         Org1
# 76647   Obj3  Energy source 10   Variable_4       0  31.12.17         Org1
# 76648   Obj3  Energy source 10   Variable_5       0  31.12.17         Org1
# 76649   Obj3  Energy source 10   Variable_6       0  31.12.17         Org1
#
#                         Cube_Variable  p_value_threshold
# 0       Energy source 1 - Consumption                0.1
# 1        Energy source 1 - Variable 1                0.1
# 2        Energy source 1 - Variable 2                0.1
# 3        Energy source 1 - Variable 3                0.1
# 4        Energy source 1 - Variable 4                0.1
# 5        Energy source 1 - Variable 5                0.1
# 6        Energy source 1 - Variable 6                0.1
# 7       Energy source 2 - Consumption                0.1
# 8        Energy source 2 - Variable 1                0.1
# 9        Energy source 2 - Variable 2                0.1
# 10       Energy source 2 - Variable 3                0.1
# 11       Energy source 2 - Variable 4                0.1
# 12       Energy source 2 - Variable 5                0.1
# 13       Energy source 2 - Variable 6                0.1
# 14      Energy source 3 - Consumption                0.1
# 15       Energy source 3 - Variable 1                0.1
# 16       Energy source 3 - Variable 2                0.1
# 17       Energy source 3 - Variable 3                0.1
# 18       Energy source 3 - Variable 4                0.1
# 19       Energy source 3 - Variable 5                0.1
# 20       Energy source 3 - Variable 6                0.1
# 21      Energy source 4 - Consumption                0.1
# 22       Energy source 4 - Variable 1                0.1
# 23       Energy source 4 - Variable 2                0.1
# 24       Energy source 4 - Variable 3                0.1
# 25       Energy source 4 - Variable 4                0.1
# 26       Energy source 4 - Variable 5                0.1
# 27       Energy source 4 - Variable 6                0.1
# 28      Energy source 5 - Consumption                0.1
# 29       Energy source 5 - Variable 1                0.1
# ...                               ...                ...
# 76620    Energy source 6 - Variable 5                0.1
# 76621    Energy source 6 - Variable 6                0.1
# 76622   Energy source 7 - Consumption                0.1
# 76623    Energy source 7 - Variable 1                0.1
# 76624    Energy source 7 - Variable 2                0.1
# 76625    Energy source 7 - Variable 3                0.1
# 76626    Energy source 7 - Variable 4                0.1
# 76627    Energy source 7 - Variable 5                0.1
# 76628    Energy source 7 - Variable 6                0.1
# 76629   Energy source 8 - Consumption                0.1
# 76630    Energy source 8 - Variable 1                0.1
# 76631    Energy source 8 - Variable 2                0.1
# 76632    Energy source 8 - Variable 3                0.1
# 76633    Energy source 8 - Variable 4                0.1
# 76634    Energy source 8 - Variable 5                0.1
# 76635    Energy source 8 - Variable 6                0.1
# 76636   Energy source 9 - Consumption                0.1
# 76637    Energy source 9 - Variable 1                0.1
# 76638    Energy source 9 - Variable 2                0.1
# 76639    Energy source 9 - Variable 3                0.1
# 76640    Energy source 9 - Variable 4                0.1
# 76641    Energy source 9 - Variable 5                0.1
# 76642    Energy source 9 - Variable 6                0.1
# 76643  Energy source 10 - Consumption                0.1
# 76644   Energy source 10 - Variable 1                0.1
# 76645   Energy source 10 - Variable 2                0.1
# 76646   Energy source 10 - Variable 3                0.1
# 76647   Energy source 10 - Variable 4                0.1
# 76648   Energy source 10 - Variable 5                0.1
# 76649   Energy source 10 - Variable 6                0.1
#
# [76650 rows x 8 columns]

# %%
df.dtypes
# Out:
# Object                object
# Energy_Source         object
# Feature               object
# Value                  int64
# Date                  object
# Organization          object
# Cube_Variable         object
# p_value_threshold    float64
# dtype: object

# %%
df.Date=pd.to_datetime(df.Date, format='%d.%m.%y') # преобразуем Date из строки в дату
df.sort_values(["Object", "Energy_Source", "Feature", "Date"], inplace=True)

threshold = df['p_value_threshold'].unique()[0]	# граница значимости коэффициента лин регрессии
organizations = df["Organization"].unique().tolist() # список организаций
output_DF_cols = ["Object", "Cube_Variable", "r2_adj", "Intercept", "Significance", "coef", "p_value", "Usefull"]

FULL_DFS = [] # объект хранения результатов расчетов всех моделей

# %%
for organization in organizations:
    print(organization)

    out_dfs = [] # список с результатами расчетов по срезам объект и энергоресурс
    
    organization_DF = df[(df["Organization"] == organization)] # берем срез по организации
    
    objects = list(set(organization_DF["Object"].tolist())) # выделяем объекты
    sources  = list(set(organization_DF["Energy_Source"].tolist())) # выделяем энергоресурсы
    combination = list(itertools.product(objects, sources)) # находим уникальные сочетания

    for object, source in combination:
        print((object, source))
        # берем срез
        initialDF = organization_DF[(organization_DF["Object"] == object) & (organization_DF["Energy_Source"] == source)] # срезаем данные по объекту и энергоресурсу

        Cube_Variables =initialDF['Cube_Variable'].unique().tolist()

        new_DF = make_new_DF(initialDF) # формируем датафрейм с необходимой структурой
        new_DF = fill_new_DF(initialDF, new_DF, object, source) # заполняем его данными
        new_DF = new_DF[(new_DF["Consumption"] > 0)] # отбрасываем значения с нулевым потреблением

        # готовим обучающие данные для модели
        y = new_DF.Consumption
        X = new_DF[new_DF.columns[3:]]
        X = sm.add_constant(X)

        # строим и обучаем линейную регрессию
        try:
            model = sm.OLS(y, X).fit()
            print("OK\n")
            output_DF = generate_out_df(model, Cube_Variables, object, output_DF_cols) # выводим результаты модели в отдельный датафрейм
        except ValueError:
            print("Blank DF\n")
            output_DF = generate_blank_out_df(Cube_Variables, object, output_DF_cols)

        out_dfs.append(output_DF)  # сохраняем результаты расчет по объекту и энергоресурсу
    
    full_output_DF = pd.concat(out_dfs, ignore_index=True) # объединение результатов расчета по объектам и энергоресурсам в один датафрейм
    full_output_DF['Organization'] = organization

    FULL_DFS.append(full_output_DF) # сохраняем расчеты по организации
    
FINAL_DF = pd.concat(FULL_DFS, ignore_index=True) # объединяем расчеты по организациям в один объект
# Out:
# Org1
# ('Obj1', 'Energy source 1')
# OK
#
# ('Obj1', 'Energy source 3')
# Blank DF
#
# ('Obj1', 'Energy source 8')
# Blank DF
#
# ('Obj1', 'Energy source 10')
# Blank DF
#
# ('Obj1', 'Energy source 7')
# Blank DF
#
# ('Obj1', 'Energy source 5')
# Blank DF
#
# ('Obj1', 'Energy source 6')
# Blank DF
#
# ('Obj1', 'Energy source 9')
# Blank DF
#
# ('Obj1', 'Energy source 4')
# Blank DF
#
# ('Obj1', 'Energy source 2')
# Blank DF
#
# ('Obj3', 'Energy source 1')
# Blank DF
#
# ('Obj3', 'Energy source 3')
# Blank DF
#
# ('Obj3', 'Energy source 8')
# Blank DF
#
# ('Obj3', 'Energy source 10')
# Blank DF
#
# ('Obj3', 'Energy source 7')
# Blank DF
#
# ('Obj3', 'Energy source 5')
# Blank DF
#
# ('Obj3', 'Energy source 6')
# Blank DF
#
# ('Obj3', 'Energy source 9')
# Blank DF
#
# ('Obj3', 'Energy source 4')
# Blank DF
#
# ('Obj3', 'Energy source 2')
# Blank DF
#
# ('Obj2', 'Energy source 1')
# Blank DF
#
# ('Obj2', 'Energy source 3')
# Blank DF
#
# ('Obj2', 'Energy source 8')
# Blank DF
#
# ('Obj2', 'Energy source 10')
# Blank DF
#
# ('Obj2', 'Energy source 7')
# Blank DF
#
# ('Obj2', 'Energy source 5')
# Blank DF
#
# ('Obj2', 'Energy source 6')
# Blank DF
#
# ('Obj2', 'Energy source 9')
# Blank DF
#
# ('Obj2', 'Energy source 4')
# Blank DF
#
# ('Obj2', 'Energy source 2')
# Blank DF

# %% [markdown]
# Как можно заметить, в данных много нулевых значений и расчеты произвелись только для Obj1. Посмотрим...

# %%
FINAL_DF[FINAL_DF.Object=='Obj1']
# Out:
#    Object                   Cube_Variable    r2_adj      Intercept  \
# 0    Obj1    Energy source 1 - Variable 1       NaN            NaN
# 1    Obj1    Energy source 1 - Variable 2       NaN            NaN
# 2    Obj1    Energy source 1 - Variable 3       NaN            NaN
# 3    Obj1    Energy source 1 - Variable 4       NaN            NaN
# 4    Obj1    Energy source 1 - Variable 5       NaN            NaN
# 5    Obj1    Energy source 1 - Variable 6       NaN            NaN
# 6    Obj1   Energy source 1 - Consumption  0.677439  378806.950115
# 7    Obj1   Energy source 3 - Consumption       NaN            NaN
# 8    Obj1    Energy source 3 - Variable 1       NaN            NaN
# 9    Obj1    Energy source 3 - Variable 2       NaN            NaN
# 10   Obj1    Energy source 3 - Variable 3       NaN            NaN
# 11   Obj1    Energy source 3 - Variable 4       NaN            NaN
# 12   Obj1    Energy source 3 - Variable 5       NaN            NaN
# 13   Obj1    Energy source 3 - Variable 6       NaN            NaN
# 14   Obj1   Energy source 8 - Consumption       NaN            NaN
# 15   Obj1    Energy source 8 - Variable 1       NaN            NaN
# 16   Obj1    Energy source 8 - Variable 2       NaN            NaN
# 17   Obj1    Energy source 8 - Variable 3       NaN            NaN
# 18   Obj1    Energy source 8 - Variable 4       NaN            NaN
# 19   Obj1    Energy source 8 - Variable 5       NaN            NaN
# 20   Obj1    Energy source 8 - Variable 6       NaN            NaN
# 21   Obj1  Energy source 10 - Consumption       NaN            NaN
# 22   Obj1   Energy source 10 - Variable 1       NaN            NaN
# 23   Obj1   Energy source 10 - Variable 2       NaN            NaN
# 24   Obj1   Energy source 10 - Variable 3       NaN            NaN
# 25   Obj1   Energy source 10 - Variable 4       NaN            NaN
# 26   Obj1   Energy source 10 - Variable 5       NaN            NaN
# 27   Obj1   Energy source 10 - Variable 6       NaN            NaN
# 28   Obj1   Energy source 7 - Consumption       NaN            NaN
# 29   Obj1    Energy source 7 - Variable 1       NaN            NaN
# ..    ...                             ...       ...            ...
# 40   Obj1    Energy source 5 - Variable 5       NaN            NaN
# 41   Obj1    Energy source 5 - Variable 6       NaN            NaN
# 42   Obj1   Energy source 6 - Consumption       NaN            NaN
# 43   Obj1    Energy source 6 - Variable 1       NaN            NaN
# 44   Obj1    Energy source 6 - Variable 2       NaN            NaN
# 45   Obj1    Energy source 6 - Variable 3       NaN            NaN
# 46   Obj1    Energy source 6 - Variable 4       NaN            NaN
# 47   Obj1    Energy source 6 - Variable 5       NaN            NaN
# 48   Obj1    Energy source 6 - Variable 6       NaN            NaN
# 49   Obj1   Energy source 9 - Consumption       NaN            NaN
# 50   Obj1    Energy source 9 - Variable 1       NaN            NaN
# 51   Obj1    Energy source 9 - Variable 2       NaN            NaN
# 52   Obj1    Energy source 9 - Variable 3       NaN            NaN
# 53   Obj1    Energy source 9 - Variable 4       NaN            NaN
# 54   Obj1    Energy source 9 - Variable 5       NaN            NaN
# 55   Obj1    Energy source 9 - Variable 6       NaN            NaN
# 56   Obj1   Energy source 4 - Consumption       NaN            NaN
# 57   Obj1    Energy source 4 - Variable 1       NaN            NaN
# 58   Obj1    Energy source 4 - Variable 2       NaN            NaN
# 59   Obj1    Energy source 4 - Variable 3       NaN            NaN
# 60   Obj1    Energy source 4 - Variable 4       NaN            NaN
# 61   Obj1    Energy source 4 - Variable 5       NaN            NaN
# 62   Obj1    Energy source 4 - Variable 6       NaN            NaN
# 63   Obj1   Energy source 2 - Consumption       NaN            NaN
# 64   Obj1    Energy source 2 - Variable 1       NaN            NaN
# 65   Obj1    Energy source 2 - Variable 2       NaN            NaN
# 66   Obj1    Energy source 2 - Variable 3       NaN            NaN
# 67   Obj1    Energy source 2 - Variable 4       NaN            NaN
# 68   Obj1    Energy source 2 - Variable 5       NaN            NaN
# 69   Obj1    Energy source 2 - Variable 6       NaN            NaN
#
#     Significance        coef   p_value  Usefull Organization
# 0            NaN   86.440032  0.009860      1.0         Org1
# 1            NaN  524.053332  0.038987      1.0         Org1
# 2            NaN    0.000000  1.000000      0.0         Org1
# 3            NaN    0.000000  1.000000      0.0         Org1
# 4            NaN    0.000000  1.000000      0.0         Org1
# 5            NaN    0.000000  1.000000      0.0         Org1
# 6       0.002492         NaN       NaN      NaN         Org1
# 7            NaN    0.000000       NaN      NaN         Org1
# 8            NaN    0.000000       NaN      NaN         Org1
# 9            NaN    0.000000       NaN      NaN         Org1
# 10           NaN    0.000000       NaN      NaN         Org1
# 11           NaN    0.000000       NaN      NaN         Org1
# 12           NaN    0.000000       NaN      NaN         Org1
# 13           NaN    0.000000       NaN      NaN         Org1
# 14           NaN    0.000000       NaN      NaN         Org1
# 15           NaN    0.000000       NaN      NaN         Org1
# 16           NaN    0.000000       NaN      NaN         Org1
# 17           NaN    0.000000       NaN      NaN         Org1
# 18           NaN    0.000000       NaN      NaN         Org1
# 19           NaN    0.000000       NaN      NaN         Org1
# 20           NaN    0.000000       NaN      NaN         Org1
# 21           NaN    0.000000       NaN      NaN         Org1
# 22           NaN    0.000000       NaN      NaN         Org1
# 23           NaN    0.000000       NaN      NaN         Org1
# 24           NaN    0.000000       NaN      NaN         Org1
# 25           NaN    0.000000       NaN      NaN         Org1
# 26           NaN    0.000000       NaN      NaN         Org1
# 27           NaN    0.000000       NaN      NaN         Org1
# 28           NaN    0.000000       NaN      NaN         Org1
# 29           NaN    0.000000       NaN      NaN         Org1
# ..           ...         ...       ...      ...          ...
# 40           NaN    0.000000       NaN      NaN         Org1
# 41           NaN    0.000000       NaN      NaN         Org1
# 42           NaN    0.000000       NaN      NaN         Org1
# 43           NaN    0.000000       NaN      NaN         Org1
# 44           NaN    0.000000       NaN      NaN         Org1
# 45           NaN    0.000000       NaN      NaN         Org1
# 46           NaN    0.000000       NaN      NaN         Org1
# 47           NaN    0.000000       NaN      NaN         Org1
# 48           NaN    0.000000       NaN      NaN         Org1
# 49           NaN    0.000000       NaN      NaN         Org1
# 50           NaN    0.000000       NaN      NaN         Org1
# 51           NaN    0.000000       NaN      NaN         Org1
# 52           NaN    0.000000       NaN      NaN         Org1
# 53           NaN    0.000000       NaN      NaN         Org1
# 54           NaN    0.000000       NaN      NaN         Org1
# 55           NaN    0.000000       NaN      NaN         Org1
# 56           NaN    0.000000       NaN      NaN         Org1
# 57           NaN    0.000000       NaN      NaN         Org1
# 58           NaN    0.000000       NaN      NaN         Org1
# 59           NaN    0.000000       NaN      NaN         Org1
# 60           NaN    0.000000       NaN      NaN         Org1
# 61           NaN    0.000000       NaN      NaN         Org1
# 62           NaN    0.000000       NaN      NaN         Org1
# 63           NaN    0.000000       NaN      NaN         Org1
# 64           NaN    0.000000       NaN      NaN         Org1
# 65           NaN    0.000000       NaN      NaN         Org1
# 66           NaN    0.000000       NaN      NaN         Org1
# 67           NaN    0.000000       NaN      NaN         Org1
# 68           NaN    0.000000       NaN      NaN         Org1
# 69           NaN    0.000000       NaN      NaN         Org1
#
# [70 rows x 9 columns]
